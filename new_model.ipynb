# %%
# %pip install transformers

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d5a2c54a-c679-4a8c-a23d-ae2c1dbf9b2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5a2c54a-c679-4a8c-a23d-ae2c1dbf9b2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from IPython.display import Audio


Audio('happy.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4da7ac5f-fa23-40c6-99b5-75fd52a0e9a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4da7ac5f-fa23-40c6-99b5-75fd52a0e9a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Audio('happy1.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a672097e-03fc-4826-9d4d-5bce12fff7bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a672097e-03fc-4826-9d4d-5bce12fff7bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Audio('happy2.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-67736037-2096-4a65-aa3d-5bfec9b31ee6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67736037-2096-4a65-aa3d-5bfec9b31ee6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Audio('sad.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e10008a8-511a-42e2-8929-413f95c21ac6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e10008a8-511a-42e2-8929-413f95c21ac6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Audio('angry.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import HubertForSequenceClassification, Wav2Vec2FeatureExtractor
import torchaudio
import torch

feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/hubert-large-ls960-ft")
model = HubertForSequenceClassification.from_pretrained("xbgoose/hubert-speech-emotion-recognition-russian-dusha-finetuned")
num2emotion = {0: 'neutral', 1: 'angry', 2: 'positive', 3: 'sad', 4: 'other'}

filepath = "angry.ogg"

waveform, sample_rate = torchaudio.load(filepath, normalize=True)
transform = torchaudio.transforms.Resample(sample_rate, 16000)
waveform = transform(waveform)

inputs = feature_extractor(
        waveform,
        sampling_rate=feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        max_length=16000 * 10,
        truncation=True
    )

logits = model(inputs['input_values'][0]).logits
predictions = torch.argmax(logits, dim=-1)
predicted_emotion = num2emotion[predictions.numpy()[0]]
if predicted_emotion in ["fearful", "angry"]:
    predicted_emotion= "anger_fear"
elif predicted_emotion == "sad":
    predicted_emotion= "sadness"
elif predicted_emotion == "positive":
    predicted_emotion= "joy_excited"
elif predicted_emotion in ["neutral", "calm"]:
    predicted_emotion= "calm_content"
elif predicted_emotion == "surprised":
    predicted_emotion= "curious_reflective"
else:
    predicted_emotion= ('other')
print(predicted_emotion)
# Out:
# anger_fear

# %%
filepath = "sad.ogg"
waveform, sample_rate = torchaudio.load(filepath, normalize=True)
transform = torchaudio.transforms.Resample(sample_rate, 16000)
waveform = transform(waveform)

inputs = feature_extractor(
        waveform,
        sampling_rate=feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        max_length=16000 * 10,
        truncation=True
    )

logits = model(inputs['input_values'][0]).logits
predictions = torch.argmax(logits, dim=-1)
predicted_emotion = num2emotion[predictions.numpy()[0]]
if predicted_emotion in ["fearful", "angry"]:
    predicted_emotion= "anger_fear"
elif predicted_emotion == "sad":
    predicted_emotion= "sadness"
elif predicted_emotion == "positive":
    predicted_emotion= "joy_excited"
elif predicted_emotion in ["neutral", "calm"]:
    predicted_emotion= "calm_content"
elif predicted_emotion == "surprised":
    predicted_emotion= "curious_reflective"
else:
    predicted_emotion= ('other')
print(predicted_emotion)
# Out:
# sadness

# %%
filepath = "happy.ogg"

waveform, sample_rate = torchaudio.load(filepath, normalize=True)
transform = torchaudio.transforms.Resample(sample_rate, 16000)
waveform = transform(waveform)

inputs = feature_extractor(
        waveform,
        sampling_rate=feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        max_length=16000 * 10,
        truncation=True
    )

logits = model(inputs['input_values'][0]).logits
predictions = torch.argmax(logits, dim=-1)
predicted_emotion = num2emotion[predictions.numpy()[0]]
if predicted_emotion in ["fearful", "angry"]:
    predicted_emotion= "anger_fear"
elif predicted_emotion == "sad":
    predicted_emotion= "sadness"
elif predicted_emotion == "positive":
    predicted_emotion= "joy_excited"
elif predicted_emotion in ["neutral", "calm"]:
    predicted_emotion= "calm_content"
elif predicted_emotion == "surprised":
    predicted_emotion= "curious_reflective"
else:
    predicted_emotion= ('other')
print(predicted_emotion)
# Out:
# joy_excited

# %%
filepath = "happy1.ogg"

waveform, sample_rate = torchaudio.load(filepath, normalize=True)
transform = torchaudio.transforms.Resample(sample_rate, 16000)
waveform = transform(waveform)

inputs = feature_extractor(
        waveform,
        sampling_rate=feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        max_length=16000 * 10,
        truncation=True
    )

logits = model(inputs['input_values'][0]).logits
predictions = torch.argmax(logits, dim=-1)
predicted_emotion = num2emotion[predictions.numpy()[0]]
if predicted_emotion in ["fearful", "angry"]:
    predicted_emotion= "anger_fear"
elif predicted_emotion == "sad":
    predicted_emotion= "sadness"
elif predicted_emotion == "positive":
    predicted_emotion= "joy_excited"
elif predicted_emotion in ["neutral", "calm"]:
    predicted_emotion= "calm_content"
elif predicted_emotion == "surprised":
    predicted_emotion= "curious_reflective"
else:
    predicted_emotion= ('other')
print(predicted_emotion)
# Out:
# joy_excited

# %%
filepath = "happy2.ogg"

waveform, sample_rate = torchaudio.load(filepath, normalize=True)
transform = torchaudio.transforms.Resample(sample_rate, 16000)
waveform = transform(waveform)

inputs = feature_extractor(
        waveform,
        sampling_rate=feature_extractor.sampling_rate,
        return_tensors="pt",
        padding=True,
        max_length=16000 * 10,
        truncation=True
    )

logits = model(inputs['input_values'][0]).logits
predictions = torch.argmax(logits, dim=-1)
predicted_emotion = num2emotion[predictions.numpy()[0]]
if predicted_emotion in ["fearful", "angry"]:
    predicted_emotion= "anger_fear"
elif predicted_emotion == "sad":
    predicted_emotion= "sadness"
elif predicted_emotion == "positive":
    predicted_emotion= "joy_excited"
elif predicted_emotion in ["neutral", "calm"]:
    predicted_emotion= "calm_content"
elif predicted_emotion == "surprised":
    predicted_emotion= "curious_reflective"
else:
    predicted_emotion= ('other')
print(predicted_emotion)
# Out:
# joy_excited
